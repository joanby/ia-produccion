# %% [markdown]
# # Vibe Coding y Depuración 🧠💻
#
# El término **“Vibe Coding”** es una forma cariñosa de referirse a la programación asistida por **LLMs (Modelos de Lenguaje de Gran Escala)**. Es especialmente fácil —y genial— hacerlo con **Cursor** ⚡.
#
# Sin embargo, existen ciertas **técnicas clave** para sacar el máximo partido a esta forma de trabajar, que veremos con detalle en el curso. Aquí tienes algunos **consejos esenciales** 👇

# %% [markdown]
# 1. 🗓️ **Incluye siempre la fecha actual** en tus prompts cuando le pidas a un LLM (como ChatGPT o Claude) que escriba código, e indícale que use las **versiones más recientes de las APIs**. Esto es especialmente importante con la API de OpenAI, ya que ChatGPT a veces intenta usar versiones antiguas de su propia API.
#
# 2. ✂️ En tus prompts, **pide que el código sea lo más corto y simple posible**. Los LLMs tienden a agregar comprobaciones innecesarias que solo hacen que el código sea más confuso y difícil de depurar.
#
# 3. 🤖 **Haz la misma pregunta a varios LLMs** (por ejemplo, ChatGPT, Claude, Gemini) y elige la respuesta que te parezca **más clara y sencilla**.
#
# 4. 🔍 **Toma la respuesta de un LLM** y pídele a **otro modelo** que la revise, verificando si es correcta y si puede simplificarse o explicarse mejor.
#
# 5. 🧩 Pide al LLM que te dé **tres variaciones** distintas para resolver un problema, y elige la que sea más clara y mantenible.

# %% [markdown]
# ## Vibe Coding para proyectos grandes 🚀

# %% [markdown]
# Evita pedirle a un LLM que genere **bloques de 100 o 200 líneas de código** de una sola vez. Aunque puede parecer más rápido, será mucho más difícil de **depurar** y entender (a menos que ya tengas mucha experiencia).
#
# En su lugar, sigue este enfoque:
#
# 1. 🔹 **Divide el problema** en pasos pequeños e independientes que puedas probar fácilmente.
# 2. 🤔 Si no sabes cómo dividirlo, ¡pídele al propio LLM que te ayude a hacerlo!
# 3. 🧱 Para cada bloque:
#    - Usa los consejos anteriores para pedirle al LLM que genere el código.
#    - Pídele también que escriba **tests** para validar que el código funciona correctamente.
#    - Ejecuta tú mismo las pruebas y asegúrate de que todo funcione bien.
#
# Este método te permitirá **construir proyectos grandes con seguridad y confianza** ✅.
#
# ## 🌟 Regla de oro: ¡empieza pequeño y avanza paso a paso!
