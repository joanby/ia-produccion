# %% [markdown]
# # 🧩 Guía de Supervivencia para la Depuración (Debugging Survival Guide)
#
# ## La clave: **reproducir tu problema en 5-10 líneas de código**
#
# Encontrarte con una excepción puede ser frustrante 😣, especialmente si no sabes por dónde empezar a solucionarla. ¡Pero este es el momento donde más aprendes! 💪 Resolver problemas difíciles es una excelente forma de adquirir experiencia, y cuando logras hacerlo, la satisfacción es enorme.
#
# Y recuerda: ¡estoy aquí para ayudarte si te atascas! 🚀

# %% [markdown]
# ### 🔍 Antes de empezar
#
# Aquí tienes una introducción sobre **Excepciones**, **Stack Traces**, **Manejo de Errores** y mucho más:
#
# 🔗 https://chatgpt.com/share/6806383c-ab38-8012-b21f-61af665bb900
#
# Además, revisa [esta guía](https://chatgpt.com/share/681f691b-6644-8012-b07d-207c68f259d5) si no sabes cómo hacer una **captura de pantalla** correctamente (¡nada de fotos borrosas de la pantalla! 📸).

# %% [markdown]
# ### 🧠 Fórmula para depurar: **recrear el error en 10 líneas de código o menos**
#
# La depuración (debugging) es tanto **arte como ciencia**. La mejor forma de dominarla es practicando, pero aquí tienes las **técnicas esenciales**:
#
# 1. 🧩 **Recrear**
#    Asegúrate de **reproducir el problema de forma consistente**. Si no puedes hacerlo dos veces seguidas, aún no lo tienes completamente identificado.
#
# 2. ✂️ **Simplificar**
#    Reduce tu código al **mínimo necesario** para reproducir el error. Es muy común que la gente envíe 100 o más líneas de código diciendo “esto no funciona, ayúdame”, pero lo primero que hay que hacer es aislar el núcleo del problema.
#
#    Intenta dejarlo en **10-20 líneas** o incluso menos. En una ocasión, logré mostrar a un alumno cómo reproducir su error con ¡solo 2 líneas de código! 😅
#
#    💡 Es mucho más fácil para **ti mismo** hacer esta simplificación que para cualquier otra persona. Aunque sea tedioso, casi siempre es el mejor punto de partida. Además, ¡muchas veces encuentras el problema tú solo mientras simplificas!
#
# 3. 🆘 **Pide ayuda**
#    Si después de recrear y simplificar el error sigues sin entender qué ocurre, **pide ayuda**. Puedes consultar con ChatGPT, Claude u otros modelos, compartiendo:
#    - El **fragmento mínimo de código** que reproduce el error.
#    - El **stack trace completo** del error.
#
#    Y, por supuesto, también puedes contactarme directamente — estoy aquí para asegurarme de que tu experiencia de aprendizaje sea excelente 🤝.

# %% [markdown]
# ### ⚡ Cómo obtener ayuda rápidamente
#
# Para que pueda ayudarte de la forma más efectiva posible, sigue estos pasos:
#
# 1. 🔹 **Simplifica el problema** tanto como puedas, dejando un ejemplo pequeño que sea fácil de ejecutar.
# 2. 🧾 **Incluye el stack trace completo** y una **captura de pantalla nítida**, no una foto (consulta [esta guía](https://chatgpt.com/share/681f691b-6644-8012-b07d-207c68f259d5) si tienes dudas).
# 3. 📧 **Envíame un correo** a `ed@edwarddonner.com`.
#
# 💡 Consejo extra: si has usado **Google Colab**, es una forma fantástica de compartir tu problema. Así puedo **reproducirlo exactamente**, aplicar la solución y devolvértelo corregido al instante.
#
# 👉 ¡Espero poder ayudarte pronto y acompañarte en tu proceso de aprendizaje!
