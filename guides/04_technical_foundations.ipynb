# %% [markdown]
# # Fundamentos Técnicos
#
# Es fundamental que te sientas cómodo con los **conceptos técnicos básicos** con los que trabajaremos. Esto hará que tu experiencia en el curso sea mucho mejor — puede resultar muy frustrante si no comprendes lo que está ocurriendo.
#
# Estas guías están pensadas para **fortalecer tu confianza** en las tecnologías que utilizaremos a lo largo del curso.

# %% [markdown]
# ## Tema 1: ChatGPT vs API de OpenAI
#
# ### ¿Cuál es la diferencia entre ChatGPT y la API de GPT, ambas ofrecidas por OpenAI?
#
# #### ChatGPT es una herramienta para usuarios finales. Es un producto de chat diseñado para consumidores que usan la IA.
# - Tiene un plan gratuito y también planes de suscripción con más funciones.
# - Los planes de suscripción ofrecen al usuario acceso casi ilimitado al producto de chat.
#
# #### La API es un servicio destinado a ingenieros de IA — desarrolladores de software y científicos de datos — que trabajan en otros productos comerciales.
# - Permite a personas técnicas, como tú y como yo, acceder a los **modelos subyacentes** (como “GPT-4.1” y “o3”) para que podamos construir nuestros propios productos.
# - Si quisiéramos, podríamos crear nuestra **propia versión de ChatGPT** usando la API, y cobrar a nuestros usuarios finales por utilizarla.
# - Como la mayoría de las APIs, OpenAI cobra una pequeña cantidad basada en el uso. En la mayoría de los ejemplos del curso que usan **gpt-4o-mini**, el coste ronda los **$0.001 por llamada a la API**.
#
# ### Pago $20/mes por ChatGPT — ¿por qué necesito pagar más por la API?
#
# - Ahora debería estar más claro: la API **no está destinada a consumidores**, sino a **ingenieros** que desarrollan sus propias plataformas para ofrecerlas a terceros.
# - Si la suscripción diera acceso libre a la API, podrías ofrecer herramientas tipo ChatGPT a otros más barato que OpenAI… ¡y dejarles sin negocio!
# - Ten en cuenta que **cada llamada a la API puede requerir billones de operaciones matemáticas**, y todo ese cómputo **consume electricidad**.
#
# En lugar de usar la API, también puedes ejecutar **modelos de código abierto localmente**, pero normalmente estos tienen **1.000 veces menos capacidad de cálculo** — y aun así, aunque parezca pequeño, ese procesamiento **también impacta en tu factura eléctrica**.

# %% [markdown]
# ## Tema 2: Hacer una captura de pantalla
#
# Puede que ya estés familiarizado con cómo hacer una **captura de pantalla** en tu ordenador, pero si no (o si piensas que significa hacer una foto con tu cámara 😅), revisa este tutorial:
#
# https://chatgpt.com/share/681f691b-6644-8012-b07d-207c68f259d5

# %% [markdown]
# ## Tema 3: Variables de entorno y el archivo `.env`
#
# Este tutorial te explica todo lo que necesitas saber sobre los **archivos `.env`**.
#
# No es necesario que añadas el archivo `.env` a `.gitignore`, ya que eso **ya está configurado por defecto** en este proyecto. Aun así, la guía explica muy bien **por qué es importante**.
#
# https://chatgpt.com/share/68061e89-dd84-8012-829d-9f4506c7baaa

# %% [markdown]
# ## Tema 4: Fundamentos de redes
#
# Este tutorial cubre los **conceptos básicos de redes** y los problemas típicos con **certificados, VPNs, DNS** y otros.
#
# Las secciones ofrecen un resumen general; puedes pedirle a ChatGPT que amplíe cualquier apartado si lo consideras relevante para tu caso.
#
# https://chatgpt.com/share/680620ec-3b30-8012-8c26-ca86693d0e3d
#
# Y aquí tienes una guía más detallada para resolver problemas de **SSL / certificados**, algo común en entornos corporativos:
#
# https://chatgpt.com/share/68c2efc4-0280-8012-933b-5e89d7db6b58

# %% [markdown]
# ## Tema 5: APIs y librerías cliente – introducción
#
# Usaremos **APIs** constantemente en este curso. 🔗
#
# Es fundamental entender los **principios básicos** de lo que ocurre cuando hacemos una llamada a una API, y sentirse cómodo con términos como **“endpoint”** y **“librería cliente”**.
#
# Revisa esta guía:
#
# https://chatgpt.com/share/68062432-43c8-8012-ad91-6311d4ad5858

# %% [markdown]
# ## Tema 6: uv, gestión de paquetes y entornos
#
# Este tutorial explica cómo funciona la **gestión de dependencias** y por qué **amamos `uv`** ❤️.
# Incluye también un curso rápido sobre cómo usarlo correctamente.
#
# https://chatgpt.com/share/68c34d46-18a0-8012-8d65-0a0cce615912
#
# Ten en cuenta que esta guía sugiere usar `uv run python xxx`, lo cual funciona perfectamente, pero simplemente `uv run xxx` también es válido y más común.
