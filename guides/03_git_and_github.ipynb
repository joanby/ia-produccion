# %% [markdown]
# # Git y GitHub

# %% [markdown]
# Esta guía trata sobre el uso del **control de versiones de código fuente**: **Git y GitHub**. 🧑‍💻
#
# Al finalizarla, deberías sentirte cómodo con los procesos cotidianos de control de código, incluyendo cómo **obtener el código más reciente (pull)** y **enviar un PR (Pull Request)** para fusionar tus propios cambios.

# %% [markdown]
# ### 📘 Introducción básica
#
# Aquí tienes una introducción a **Git y GitHub**, tanto para usuarios de **PC** como de **Mac**:
#
# https://chatgpt.com/share/68061486-08b8-8012-97bc-3264ad5ebcd4

# %% [markdown]
# ### 🔄 Obtener el código más reciente
#
# Regularmente agrego **mejoras al curso**, incluyendo nuevos ejemplos, ejercicios y materiales.
#
# Aquí tienes las instrucciones para traer esas actualizaciones — tanto de la forma **fácil** como de la forma **rigurosa**:
#
# https://chatgpt.com/share/6806178b-0700-8012-836f-7e87b2670b7b

# %% [markdown]
# ### 🤝 Contribuir con tus cambios al repositorio para compartir tus aportes con otros
#
# Aquí tienes las instrucciones paso a paso para **enviar un Pull Request (PR)**.
#
# Estaré encantado de incluir tus contribuciones 🙌. Aportan valor a todos los demás estudiantes y, además, ¡me encanta verlas! Como beneficio adicional, obtendrás **reconocimiento en GitHub** como colaborador del repositorio.
#
# Dado que este curso implica crear **repositorios completos**, te recomiendo crear un **archivo Markdown o un cuaderno de Jupyter Notebook** que enlace a tu propio repositorio, y luego incluirlo en la carpeta **community_contributions** mediante un PR.
#
# Aquí tienes las instrucciones y explicaciones detalladas:
#
# https://chatgpt.com/share/6873c22b-2a1c-8012-bc9a-debdcf7c835b

# %% [markdown]
# ### 🧠 Si quieres convertirte en un experto en Git
#
# Si deseas profundizar en el uso avanzado de Git, aquí tienes una **guía excelente**. Léela y ¡sabrás incluso más que yo! 😄
#
# https://beej.us/guide/bggit/
