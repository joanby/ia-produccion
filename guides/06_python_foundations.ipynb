# %% [markdown]
# # Fundamentos de Python y cómo resolver errores NameError 🐍💡
#
# ## Para quienes comienzan desde cero 👶
#
# Este tutorial introductorio te ayudará a dar tus primeros pasos con los fundamentos de Python:
#
# 🔗 https://chatgpt.com/share/68063082-c2d8-8012-8d45-fa674aa1c1ed

# %% [markdown]
# ## A continuación: una guía completa de Python 🧠
#
# Voy a remitirte a nuestro amigo la IA, porque estas explicaciones están **muy bien escritas** y vienen acompañadas de **excelentes ejemplos**. Copia y pega los fragmentos de código en una nueva celda para probarlos. Elige las secciones que quieras repasar o reforzar.
#
# **Importaciones en Python:**
# 🔗 https://chatgpt.com/share/672f9f31-8114-8012-be09-29ef0d0140fb
#
# **Funciones en Python**, incluyendo argumentos por defecto:
# 🔗 https://chatgpt.com/share/672f9f99-7060-8012-bfec-46d4cf77d672
#
# **Cadenas de texto (strings)** en Python, incluyendo *slicing*, *split/join*, *replace* y literales:
# 🔗 https://chatgpt.com/share/672fb526-0aa0-8012-9e00-ad1687c04518
#
# **F-strings en Python**, incluyendo formato de números y fechas:
# 🔗 https://chatgpt.com/share/672fa125-0de0-8012-8e35-27918cbb481c
#
# **Listas, diccionarios y conjuntos (sets)** en Python, incluyendo el método `get()`:
# 🔗 https://chatgpt.com/share/672fa225-3f04-8012-91af-f9c95287da8d
#
# **Archivos en Python**, incluyendo modos, codificación, *context managers*, `Path` y `glob.glob`:
# 🔗 https://chatgpt.com/share/673b53b2-6d5c-8012-a344-221056c2f960
#
# **Clases en Python:**
# 🔗 https://chatgpt.com/share/672fa07a-1014-8012-b2ea-6dc679552715
#
# **Serialización de objetos en Python (Pickle y JSON):**
# 🔗 https://chatgpt.com/share/673b553e-9d0c-8012-9919-f3bb5aa23e31

# %% [markdown]
# ## Comprendiendo los errores NameError en Python ⚠️
#
# Es muy común encontrarse con un **NameError** en Python. Con una base sólida, deberías sentirte siempre preparado para **depurar** este tipo de errores y encontrar la causa fácilmente.
#
# 👉 El motivo más habitual, especialmente cuando trabajas en un Notebook, es **no haber ejecutado todas las celdas en orden**, por lo que el Kernel no tiene definida alguna variable o función.
#
# Si no estás seguro de cómo resolver un NameError, revisa estas dos guías paso a paso:
#
# - 🧩 [Guía inicial para entender los NameError](https://chatgpt.com/share/67958312-ada0-8012-a1d3-62b3a5fcbbfc)
# - 🧠 [Segunda guía con ejercicios prácticos](https://chatgpt.com/share/67a57e0b-0194-8012-bb50-8ea76c5995b8)
#
# Trabaja con ambas hasta sentirte completamente seguro. Aunque hay algo de repetición entre ellas, consolidarás tu comprensión.
#
# 💪 Después de esto, ¡los errores NameError dejarán de ser un problema para ti!
