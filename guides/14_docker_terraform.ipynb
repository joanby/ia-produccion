# %% [markdown]
# # Informes breves sobre Docker y Terraform
#
# Aquí tienes a un amigo en común ofreciendo un excelente tutorial autodidacta sobre los fundamentos de Docker:
#
# https://chatgpt.com/share/68c34f21-07bc-8012-b411-35cc97aff6ab
#
# Y aquí tienes una visión general igualmente excelente de Terraform para que empieces a construir infraestructura con código como un profesional. ¡No más consola de AWS!
#
# https://chatgpt.com/share/68c3513a-c194-8012-85c3-c0ea9143af5a
