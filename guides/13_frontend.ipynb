# %% [markdown]
# # Tu curso intensivo de frontend
#
# Aquí tienes una serie de siete partes desarrollada por ya-sabes-quién bajo mi dirección. ¡Está muy bien hecha! Puedes llevarla en cualquier dirección que desees.
#
# ChatGPT ha escrito esto en forma de apuntes para alguien que quiera experimentar; deberías pedirle que lo reescriba de una manera más extensa si prefieres explicaciones más profundas.
#
# 1. Repaso de HTML, CSS y JavaScript modernos
#
# https://chatgpt.com/share/68c345ee-ae34-8012-9a05-0ce43a816f9c
#
# 2. JavaScript moderno
#
# https://chatgpt.com/share/68c3495f-0c94-8012-b048-db1670aefa47
#
# 3. De JavaScript a TypeScript
#
# https://chatgpt.com/share/68c34974-b768-8012-9926-5a9ed67d59c3
#
# 4. Fundamentos de React (TypeScript)
#
# https://chatgpt.com/share/68c3498d-e340-8012-b3a3-37a28802db6a
#
# 5. React - estado, props y hooks
#
# https://chatgpt.com/share/68c349c7-e75c-8012-b1e5-b4f51bb0e27c
#
# 6. Introducción a NextJS
#
# https://chatgpt.com/share/68c349e7-e740-8012-8f0c-ba40ad7e148d
#
# 7. Modelos de renderizado de NextJS y Tailwind
#
# https://chatgpt.com/share/68c34a13-3120-8012-9a67-f53d7a0cfc99
