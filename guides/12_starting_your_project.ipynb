# %% [markdown]
# ## Cómo empezar a trabajar en tu idea
#
# Así que has tenido una idea de algo que te gustaría construir.
#
# ¡ENHORABUENA! Esa es la parte más importante ya hecha. ¡La idea lo es todo!
#
# Pero ahora no estás seguro de por dónde empezar. Recibo muchas preguntas sobre esto.
#
# Quiero darte tres consejos esenciales.

# %% [markdown]
# ## Consejo 1: Sé un científico
#
# Ser un ingeniero de IA implica llevar dos sombreros: ser ingeniero de software y científico de datos.
#
# Al comienzo de tu proyecto, es crucial quitarte el sombrero de ingeniero de software y ponerte firmemente el de científico de datos.
#
# Muchas personas con experiencia en ingeniería de software (¡yo incluido!) tienen dificultades con esto. Es común que la gente caiga en su zona de confort, haciendo preguntas sobre arquitectura, diseño, canalizaciones de datos, escalabilidad, implementación.
#
# Todas estas son excelentes preguntas, pero no son las críticas en esta etapa inicial. No son las preguntas difíciles. No harán que tu idea triunfe o fracase.
#
# Para las preguntas críticas, necesitas ser un científico.
#
# Pregúntate a ti mismo:
# 1. ¿Cómo evaluarás el éxito de tu modelo? ¿Qué medirás?
# 2. ¿Qué datos tienes y qué datos necesitas?
# 3. ¿Cómo puedes construir pequeños prototipos para probar diferentes técnicas y comprender el rendimiento del modelo?
#
# Aborda primero las preguntas científicas: qué puedes lograr con los LLMs y cómo.
#
# Y recomiendo comenzar en un Notebook antes de trabajar en módulos de Python, para obligarte a operar con esta mentalidad científica.
#
# Esto es aún más crucial con los proyectos de Agentes. Puede ser tentador dibujar un gran diagrama de arquitectura de Agentes sobre cómo colaborarán tus agentes, como un diagrama técnico. Pero esto es pensar como un ingeniero de software. Recomiendo abordarlo de manera diferente; experimenta con distintos enfoques, investiga qué funciona bien, prueba hipótesis e itera.

# %% [markdown]
# ## Consejo 2: Abraza la I+D
#
# De acuerdo, esto es bastante similar al Consejo 1, ¡pero vale la pena repetirlo!
#
# A menudo me hacen preguntas como: “Ed, quiero construir la siguiente solución. ¿Debería usar el modelo A, B o C? ¿Debería usar Agentes, RAG o ajuste fino?”
#
# Mi respuesta casi siempre es:
# - ¡Deberías hacer todo lo anterior! La clave es experimentar; (a) elabora un criterio de evaluación, (b) desarrolla un conjunto de datos curado, (c) prueba diferentes ideas y observa cómo se comportan
# - A menudo tengo una corazonada sobre cuál funcionará mejor, ¡pero mi corazonada suele estar equivocada! No confíes en mí: pruébalo tú mismo
# - Simplemente no hay sustituto para la experimentación.

# %% [markdown]
# ## Consejo 3: Sueña en grande pero empieza PEQUEÑO
#
# También suelo recibir mensajes de estudiantes que me envían 200 o 300 líneas de código diciendo: “Ed, esto no funciona bien, por favor arréglalo”. 😂
#
# Como digo en la guía de depuración: ¡así no funciona esto!
#
# Al comenzar proyectos, es fundamental empezar de forma pequeña y simple. Perfecciona cada prompt; trabaja en detalle cada paso. Asegúrate de que cada llamada al LLM funcione como deseas e itera en las entradas hasta que las respuestas sean consistentes y fiables.
#
# Si siempre trabajas de forma incremental y con bloques pequeños y comprobables, deberías tener una comprensión completa de lo que está ocurriendo.
#
# Y por supuesto, me encanta ayudar a la gente con sus proyectos y es genial ayudar a resolver problemas. Pero si abordas tu proyecto de forma incremental, siempre deberías tener claridad sobre qué parte exactamente no está funcionando, y entonces es súper eficiente para mí ayudarte.

# %% [markdown]
# # En resumen
#
# Probablemente notaste el tema común en estos tres consejos. Puede resultar desconcertante para personas sin experiencia en ciencia de datos abordar los problemas de una manera tan improvisada; parece “poco profesional” o insatisfactorio. Pero en mi opinión, esta es la habilidad más importante para convertirse en un ingeniero de IA exitoso: sentirse cómodo con la incertidumbre, disfrutar de los experimentos y abrazar el papel de científico.
