# %% [markdown]
# # La línea de comandos

# %% [markdown]
# Bienvenido a la guía para ganar confianza trabajando con la **línea de comandos**.
#
# Al finalizar esta guía, deberías sentirte cómodo trabajando desde la terminal: creando directorios, moviendo archivos ¡y mucho más! 💪

# %% [markdown]
# ## Para usuarios de Windows PC
#
# Consulta este briefing:
#
# https://chatgpt.com/share/68064acf-4d3c-8012-86a1-fb09a7c6f923

# %% [markdown]
# ## Para usuarios de Mac
#
# Consulta este briefing:
#
# https://chatgpt.com/share/68064bfe-662c-8012-8073-479c32595459

# %% [markdown]
# Experimenta todo lo que puedas para fortalecer tu confianza. 💻✨
#
# Recuerda: **ChatGPT, Claude, Gemini, DeepSeek** y otros asistentes son tus aliados. Son excelentes explicando en detalle cualquier comando de la línea de comandos.
#
# Con práctica, ¡usar la terminal se convertirá en algo completamente natural!
